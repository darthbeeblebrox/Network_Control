# %% [markdown]
# # Build the C elegans network
# Uses a graph_ml text file downloaded from https://elegans.herokuapp.com/#.

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
#Import the network and visualize it
# Note that this is a directed graph!

G = nx.read_graphml('elegansGraphML.txt',node_type=int)
# nl = G.nodes()
# print(nl)
# print(G.node[0]['neuronLabel'])
# print(type(nl[0]))
nx.draw(G,node_size=20,width=0.1)
# Out:
# C:\Users\Daniel\Anaconda3\envs\py3k\lib\site-packages\networkx\drawing\nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# C:\Users\Daniel\Anaconda3\envs\py3k\lib\site-packages\networkx\drawing\nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# C:\Users\Daniel\Anaconda3\envs\py3k\lib\site-packages\matplotlib\__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# C:\Users\Daniel\Anaconda3\envs\py3k\lib\site-packages\matplotlib\rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")

# %% [markdown]
# # Simple network statistics
# Using built-in functions from networkx

# %%
#This command takes a really long time!
# print('The average node connectivity is ',nx.average_node_connectivity(G))

#This fails for a directed graph
#print('The graph is connected:',nx.is_connected(G))

print('The graph is strongly connected:',nx.is_strongly_connected(G))
print('The graph is weakly connected:',nx.is_weakly_connected(G))

dList = nx.degree_histogram(G)
#dHist = np.histogram(dList)
plt.hist(dList)
plt.title("Histogram of degree distributions")
# Out:
# The graph is strongly connected: False
# The graph is weakly connected: True

# %%
Gcolor = nx.coloring.greedy_color(G)

#nx.draw(G,node_color=Gcolor)

D = nx.degree_centrality(G)
plt.bar(range(len(D)), D.values(), align='center')
plt.title("Degree centrality for each node")
#plt.xticks(range(len(D)), D.keys())

plt.show()

# %% [markdown]
# # Matching algorithms
# Trying to build up to the full control statistics... mostly a stub for non-completed functions

# %%
import Maximal_matching as mm

#Not implemented yet
#import directed2bipartite as db
#Gb = db.di2bi(G)
#mlist = mm.maximal_matching(G)

# %%
# Get the list of all neurons of type 'sensory' or 'motor,' which
# is a proxy for what we expect to be the controlling neurons and the
# output neurons, respectively

senseList = [d for n,d in G.nodes_iter(data=True) if d['type']=='sensory']
motorList = [d for n,d in G.nodes_iter(data=True) if d['type']=='motor']
