# %%
import networkx as nx
import matplotlib.pyplot as plt

# %matplotlib inline

#Ggml = nx.read_graphml('elegansGML.gml')
G = nx.read_adjlist('elegansAdj.csv')

#path = 'herm_chem_edgelist.txt'
#Gc = nx.read_weighted_edgelist(path, delimiter=',', create_using=None)

# %%
elarge=[(u,v) for (u,v,d) in G.edges(data=True) if 1]


pos=nx.spring_layout(G) # positions for all nodes

# nodes
nx.draw_networkx_nodes(G,pos,node_size=10)

# edges
nx.draw_networkx_edges(G,pos,edgelist=elarge,
                    width=0.1)
#nx.draw_networkx_edges(G,pos,edgelist=esmall,
#                    width=6,alpha=0.5,edge_color='b',style='dashed')

# labels
#nx.draw_networkx_labels(G,pos,font_size=20,font_family='sans-serif')

plt.axis('off')
#plt.savefig("weighted_graph.png") # save as png
# Out:
# (-0.20000000000000001,
#  1.2000000000000002,
#  -0.20000000000000001,
#  1.2000000000000002)

# %%
print(G.number_of_nodes())
print(G.number_of_edges())
# Out:
# 279
# 2287

# %%
type(G)
# Out:
# networkx.classes.graph.Graph

# %%
Ggml = nx.read_graphml('elegansGraphML.txt')

# %%
print(Ggml.number_of_nodes())
print(Ggml.number_of_edges())

#nx.draw(Ggml)

Ggml.is_directed()
# Out:
# 279
# 3089
# True

# %% [markdown]
# # Scratch
# Mostly for figuring out how the file reading works here

# %%
textline = '1 2 3'
fh = open('test.edgelist','w')
d = fh.write(textline)
fh.close()
G2 = nx.read_edgelist('test.edgelist', nodetype=int, data=(('weight',float),))
print(G2.nodes())
print(G2.edges(data = True))
# Out:
# [1, 2]
# [(1, 2, {'weight': 3.0})]

# %%
#fh = open('elegansAdjWordpad.txt','rb')

#print(fh.read())

# %%
G = nx.path_graph(4)
nx.write_gml(G, 'test.gml')
H = nx.read_gml('test.gml')
